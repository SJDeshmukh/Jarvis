# %%
import turtle
t=turtle.Turtle()
t.getscreen().bgcolor('black')
t.color('gold','orange')
t.width(5)
t.speed(0)
def ganPos(x,y):
    t.penup()
    t.goto(x,y)
    t.pendown()
t.begin_fill()    
ganPos(0,20)
t.forward(150)
t.left(90)
t.forward(20)
t.left(90)
t.forward(150)
t.left(90)
t.forward(20)
ganPos(20,50)
t.right(270)
t.forward(110)
t.left(90)
t.forward(20)
t.left(90)
t.forward(110)
t.left(90)
t.forward(20)
ganPos(40,80)
t.right(270)
t.forward(70)
t.left(90)
t.forward(20)
t.left(90)
t.forward(70)
t.left(90)
t.forward(20)
ganPos(60,130)
t.circle(15)
ganPos(75,-5)
t.right(45)
for i in range(2):
    t.circle(20,90)
    
    t.circle(20//4,90)
t.end_fill()
ganPos(-200,-10)
t.begin_fill()
t.right(225)
t.forward(150)
for i in range(7):
    
    t.right(10)
    t.forward(10)
t.forward(50)
t.right(50)
t.forward(10)
t.left(100)
t.forward(10)
t.right(50)
t.forward(80)
for i in range(2):
    t.right(10)
    t.forward(20)

t.right(12)
t.forward(80)
for i in range(5):
    t.left(10)
    t.forward(10)
t.forward(20)
t.right(150)
t.forward(40)
for i in range(4):
    t.right(20)
    t.forward(10)
t.forward(90)
for i in range(3):
    t.left(10)
    t.forward(10)
t.forward(80)
t.left(60)
t.forward(20)
t.right(120)
t.forward(20)
t.left(60)
t.forward(40)
for i in range(7):
    t.left(10)
    t.forward(5)
t.forward(70)
t.left(90)
t.forward(100)
t.right(145)
t.forward(160)
t.end_fill()
ganPos(350,-10)
t.left(57)
t.forward(160)
for i in range(15):
    t.left(5)
    t.forward(5)
t.forward(160)
for i in range(6):
    t.right(5)
    t.forward(5)
for i in range(7):
    t.left(5)
    t.forward(5)
t.forward(50)
for i in range(5):
    t.left(10)
    t.forward(8)
for i in range(25):
    t.left(10)
    t.forward(3)
ganPos(350,-10)
t.begin_fill()
t.left(70)
t.forward(130)
t.right(140)
t.forward(125)
t.left(50)
t.forward(80)
for i in range(9):
    t.left(8)
    t.forward(5)
t.forward(150)
for i in range(5):
    t.right(10)
    t.forward(10)
t.end_fill()
ganPos(65,-80)
t.left(157)
t.forward(20)
ganPos(65,-95)
t.forward(20)
ganPos(65,-110)
t.forward(20)
ganPos(160,-300)
t.left(180)
for i in range(4):
    t.left(35)
    t.forward(15)
t.forward(7)
for i in range(5):
    t.right(40)
    t.forward(10)
t.forward(7)
ganPos(190,-300)
t.left(151)
t.forward(70)
ganPos(190,-370)
t.left(90)
t.begin_fill()
for i in range(2):
    t.circle(140//4,90)
t.end_fill()
# ganPos(-280,-300)
# t.right(90)
# t.forward(300)
# for i in range(8):
#     t.pencolor(col[i]'red')
#     t.circle(40,steps=2)
#     t.forward(i)
#     t.left(45)
turtle.done()

# %%
import turtle
t=turtle.Turtle()
w=t.getscreen().bgcolor('white')
col=['red','purple','cyan','yellow','orange']

turtle.done()
