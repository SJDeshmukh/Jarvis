# %%
score=0
import random
import pyttsx3
import speech_recognition as sr
engine=pyttsx3.init()
voices=engine.getProperty('voices')
engine.setProperty('voices',voices[0].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()
    
def random_sent(fname):
    lines=open(fname).read().splitlines()
    a=random.choice(lines)
    s=sr.Recognizer()
    try:
        with sr.Microphone() as source:
            
            speak("speak")
            print(a)
            
            print("listening")
            audio=s.listen(source)
            query=s.recognize_google(audio,language="en=in")
            query=query.lower()
            print(query)
            if(a==query):
                speak("Hurrey,you scored right")
                score+=100
                speak("You scored {}".format(score))
                speak("Say yes to repeat or no to exit")
                audio=s.listen(source1)
                query1=s.recognize_google(audio,language="en=in")
                if query1=='yes':
                    random_sent("D:/sud_01.txt")
                else:
                    speak("Thank you visit again")
            else:
                speak("Wrong")
                speak("You have scored {}".format(score))
                print("Say yes to repeat or no to exit")
                speak("Say yes to repeat or no to exit")
                audio=s.listen(source1)
                query1=s.recognize_google(audio,language="en=in")
                if query1=='yes':
                    random_sent("D:/sud_01.txt")
                else:
                    speak("Thank you visit again")
                    
    except:
        pass
random_sent("D:/sud_01.txt")

# %%
score=0
import random
import pyttsx3
import speech_recognition as sr
engine=pyttsx3.init()
voices=engine.getProperty('voices')
engine.setProperty('voices',voices[0].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()
def random_sent(fname,score):
    lines=open(fname).read().splitlines()
    a=random.choice(lines)
    s=sr.Recognizer()
    try:
        with sr.Microphone() as source1:
            
            print("speak")
            print(a)
            print("listening")
            audio=s.listen(source1)
            query=s.recognize_google(audio,language="en=in")
            query=query.lower()
            print(query)
            if(a==query):
                speak("Hurrey,you scored right")
                score+=100
                speak("You scored {}".format(score))
                speak("Say yes to repeat or no to exit")
                audio=s.listen(source1)
                query1=s.recognize_google(audio,language="en=in")
                if query1=='yes':
                    random_sent("D:/sud.txt",score)
                else:
                    speak("Thank you visit again")
            else:
                speak("Wrong")
                speak("You have scored {}".format(score))
                speak("Say yes to repeat or no to exit")
                audio=s.listen(source1)
                query1=s.recognize_google(audio,language="en=in")
                if query1=='yes':
                    random_sent("D:/sud.txt",score)
                else:
                    speak("Thank you visit again")
    except:
            pass
random_sent("D:/sud_01.txt",0)
